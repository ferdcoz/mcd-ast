# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # **WAPP**

# %%
wapp_pred = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/WAPP_PRED.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# Mostrar las primeras filas para verificar la carga exitosa
print(wapp_pred.head())
# Out:
#        FECHA  WAPP_REAL   WAPP_XGB  WAPP_LGBM  WAPP_AUTOML  \
# 0 2023-06-13         44  39.193989  30.209988    33.246921
# 1 2023-06-14         40  46.290821  33.214044    34.914555
# 2 2023-06-15         26  32.549614  28.853494    32.538331
# 3 2023-06-16         23  32.224243  27.162595    24.349107
# 4 2023-06-21         51  36.969025  32.881705    24.619057
#
#    WAPP_NEURAL_PROPHET  WAPP_PROPHET  WAPP_LSTM
# 0            40.520000         31.57  27.530584
# 1            39.459999         32.29  27.419422
# 2            37.790001         30.59  27.179983
# 3            36.509998         29.40  27.289053
# 4            39.820000         32.24  27.510735

# %%
import matplotlib.pyplot as plt


# Convertir la columna FECHA a tipo datetime si aún no está en ese formato
wapp_pred['FECHA'] = pd.to_datetime(wapp_pred['FECHA'])

# Establecer la columna FECHA como el índice del DataFrame (opcional, pero puede ser útil)
wapp_pred.set_index('FECHA', inplace=True)

# %%
# Graficar las series con colores diferentes
plt.figure(figsize=(20, 6))  # Tamaño de la figura
#colors = ['#8bc34a', '#009688', '#03a9f4', '#3f51b5', '#673ab7', '#9c27b0', '#9467bd'] #'ffeb3b

#xgboost 8bc34a
#lightgbm 009688
#automl 673ab7
#neuralpro 3f51b5

#prophet 03a9f4
#lstm 9467bd

# Graficar cada serie con un color distinto
plt.plot(wapp_pred['WAPP_XGB'], label='WAPP_XGB', color='#8bc34a', linewidth=1, alpha=0.8) #925C91
plt.plot(wapp_pred['WAPP_LGBM'], label='WAPP_LGBM', color='#009688', linewidth=1, alpha=0.8) #EFE978
plt.plot(wapp_pred['WAPP_AUTOML'], label='WAPP_AUTOML', color='#673ab7', linewidth=1, alpha=0.8) #58508d
plt.plot(wapp_pred['WAPP_NEURAL_PROPHET'], label='WAPP_NEURAL_PROPHET', color='#3f51b5', linewidth=1, alpha=0.8)
plt.plot(wapp_pred['WAPP_PROPHET'], label='WAPP_PROPHET', color='#03a9f4', linewidth=1, alpha=0.8)
plt.plot(wapp_pred['WAPP_LSTM'], label='WAPP_LSTM', color='#9467bd', linewidth=1, alpha=0.8)

plt.plot(wapp_pred['WAPP_REAL'], label='WAPP_REAL', color='#f44336')
ticks = wapp_pred.index[::5]
plt.xticks(ticks, rotation=90)
# Agregar etiquetas y leyenda
#plt.xlabel('Fecha')
#plt.ylabel('Valores')
plt.title('Predicciones mensajes de Whatsapp (WAPP)')
plt.legend()


# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **TP**

# %%
tp_pred = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/TP_PRED.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# Mostrar las primeras filas para verificar la carga exitosa
print(tp_pred.head())
# Out:
#        FECHA  TP_REAL      TP_XGB     TP_LGBM   TP_AUTOML  TP_NEURAL_PROPHET  \
# 0 2023-06-13      167  171.539185  157.403670  135.731589         166.380005
# 1 2023-06-14      140  144.258972  151.234221  166.696248         155.220001
# 2 2023-06-15      135  138.950485  146.911088  140.491735         161.610001
# 3 2023-06-16       67  146.968262  131.170092  123.134691         152.139999
# 4 2023-06-21       44  133.043701  141.953766  135.731589         153.690002
#
#    TP_PROPHET     TP_LSTM
# 0      186.22  146.140823
# 1      177.30  140.688065
# 2      184.92  139.684631
# 3      175.01  144.623474
# 4      177.50  142.678391

# %%
# Convertir la columna FECHA a tipo datetime si aún no está en ese formato
tp_pred['FECHA'] = pd.to_datetime(tp_pred['FECHA'])

# Establecer la columna FECHA como el índice del DataFrame (opcional, pero puede ser útil)
tp_pred.set_index('FECHA', inplace=True)

# %%
# Graficar las series con colores diferentes
plt.figure(figsize=(14, 6))  # Tamaño de la figura

#xgboost 8bc34a
#lightgbm 009688
#automl 673ab7
#neuralpro 3f51b5

#prophet 03a9f4
#lstm 9467bd

# Graficar cada serie con un color distinto
plt.plot(tp_pred['TP_XGB'], label='TP_XGB', color='#8bc34a', linewidth=1, alpha=0.8) #925C91
plt.plot(tp_pred['TP_LGBM'], label='TP_LGBM', color='#009688', linewidth=1, alpha=0.8) #EFE978
plt.plot(tp_pred['TP_AUTOML'], label='TP_AUTOML', color='#673ab7', linewidth=1, alpha=0.8) #58508d
plt.plot(tp_pred['TP_NEURAL_PROPHET'], label='TP_NEURAL_PROPHET', color='#3f51b5', linewidth=1, alpha=0.8)
plt.plot(tp_pred['TP_PROPHET'], label='TP_PROPHET', color='#03a9f4', linewidth=1, alpha=0.8)
plt.plot(tp_pred['TP_LSTM'], label='TP_LSTM', color='#9467bd', linewidth=1, alpha=0.8)
plt.plot(tp_pred['TP_REAL'], label='TP_REAL', color='#f44336', linewidth=1.5)
#ticks = wapp_pred.index[::5]
plt.xticks(ticks, rotation=90)

# Agregar etiquetas y leyenda
#plt.xlabel('Fecha')
#plt.ylabel('Valores')
plt.ylim(40, 260)
plt.title('Prediciones Turnos Presenciales (TP)')
plt.legend(loc='upper right')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **TAD**

# %%
tad_pred = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/TAD_PRED.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# Mostrar las primeras filas para verificar la carga exitosa
print(tad_pred.head())
# Out:
#        FECHA  TAD_REAL    TAD_XGB   TAD_LGBM  TAD_AUTOML  TAD_NEURAL_PROPHET  \
# 0 2023-06-13        43  35.543991  38.271257   36.712393           52.779999
# 1 2023-06-14        41  35.982845  38.068572   35.849706           53.009998
# 2 2023-06-15        35  36.343983  36.987660   36.241077           52.639999
# 3 2023-06-16        27  35.400841  34.199071   35.701828           46.520000
# 4 2023-06-21        43  35.324577  35.340130   35.310457           53.790001
#
#    TAD_PROPHET   TAD_LSTM
# 0        43.32  35.052074
# 1        43.30  34.877159
# 2        43.17  35.020786
# 3        36.05  35.029972
# 4        43.53  35.243519

# %%
# Convertir la columna FECHA a tipo datetime si aún no está en ese formato
tad_pred['FECHA'] = pd.to_datetime(tad_pred['FECHA'])

# Establecer la columna FECHA como el índice del DataFrame (opcional, pero puede ser útil)
tad_pred.set_index('FECHA', inplace=True)

# %%
# Graficar las series con colores diferentes
plt.figure(figsize=(14, 6))  # Tamaño de la figura

#xgboost 8bc34a
#lightgbm 009688
#automl 673ab7
#neuralpro 3f51b5

#prophet 03a9f4
#lstm 9467bd

# Graficar cada serie con un color distinto
plt.plot(tad_pred['TAD_XGB'], label='TAD_XGB', color='#8bc34a', linewidth=1, alpha=0.8) #925C91
plt.plot(tad_pred['TAD_LGBM'], label='TAD_LGBM', color='#009688', linewidth=1, alpha=0.8) #EFE978
plt.plot(tad_pred['TAD_AUTOML'], label='TAD_AUTOML', color='#673ab7', linewidth=1, alpha=0.8) #58508d
plt.plot(tad_pred['TAD_NEURAL_PROPHET'], label='TAD_NEURAL_PROPHET', color='#3f51b5', linewidth=1, alpha=0.8)
plt.plot(tad_pred['TAD_PROPHET'], label='TAD_PROPHET', color='#03a9f4', linewidth=1, alpha=0.8)
plt.plot(tad_pred['TAD_LSTM'], label='TAD_LSTM', color='#9467bd', linewidth=1, alpha=0.8)

plt.plot(tad_pred['TAD_REAL'], label='TAD_REAL', color='#f44336', linewidth=1.5)
ticks = wapp_pred.index[::5]
plt.xticks(ticks, rotation=90)

# Agregar etiquetas y leyenda
#plt.xlabel('Fecha')
#plt.ylabel('Valores')
plt.ylim(20, 90)
plt.legend(loc='upper right')  # Colocar la leyenda en la esquina superior derecha


plt.title('Prediciones Trámites a Distancia (TAD)')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **PP**

# %%
pp_pred = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/PP_PRED.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# Mostrar las primeras filas para verificar la carga exitosa
print(pp_pred.head())
# Out:
#        FECHA  PP_REAL     PP_XGB    PP_LGBM  PP_AUTOML  PP_NEURAL_PROPHET  \
# 0 2023-06-13       15  13.726269  18.226381  15.432050               6.59
# 1 2023-06-14       14  13.621121  15.873389  11.036735               7.99
# 2 2023-06-15        6  15.023261  11.715580  15.914540               8.52
# 3 2023-06-16       11  14.303800  18.122227  13.536594               7.64
# 4 2023-06-21       10  15.707360  13.504766  11.837002               7.56
#
#    PP_PROPHET    PP_LSTM
# 0        7.06  14.346045
# 1       10.85  13.813084
# 2       11.72  13.961899
# 3       10.00  14.325568
# 4       10.42  14.429461

# %%
# Convertir la columna FECHA a tipo datetime si aún no está en ese formato
pp_pred['FECHA'] = pd.to_datetime(pp_pred['FECHA'])

# Establecer la columna FECHA como el índice del DataFrame (opcional, pero puede ser útil)
pp_pred.set_index('FECHA', inplace=True)

# %%
# Graficar las series con colores diferentes
plt.figure(figsize=(14, 6))  # Tamaño de la figura
# '#03a9f4', '#08cad1', '#42d6a4', '#f8f38d', '#ffb480'] ##8bc34a ##ffeb3b ##ff9800

#xgboost 8bc34a
#lightgbm 009688
#automl 673ab7
#neuralpro 3f51b5

#prophet 03a9f4
#lstm 9467bd


# Graficar cada serie con un color distinto
plt.plot(pp_pred['PP_XGB'], label='PP_XGB', color='#8bc34a', linewidth=1, alpha=0.8) #925C91
plt.plot(pp_pred['PP_LGBM'], label='PP_LGBM', color='#009688', linewidth=1, alpha=0.8) #EFE978
plt.plot(pp_pred['PP_AUTOML'], label='PP_AUTOML', color='#673ab7', linewidth=1, alpha=0.8) #58508d
plt.plot(pp_pred['PP_NEURAL_PROPHET'], label='PP_NEURAL_PROPHET', color='#3f51b5', linewidth=1, alpha=0.8)
plt.plot(pp_pred['PP_PROPHET'], label='PP_PROPHET', color='#03a9f4', linewidth=1, alpha=0.8)
plt.plot(pp_pred['PP_LSTM'], label='PP_LSTM', color='#9467bd', linewidth=1, alpha=0.8)

plt.plot(pp_pred['PP_REAL'], label='PP_REAL', color='#f44336', linewidth=1.5)
ticks = wapp_pred.index[::5]
plt.xticks(ticks, rotation=90)

# Agregar etiquetas y leyenda
#plt.xlabel('Fecha')
#plt.ylabel('Valores')
plt.title('Prediciones Planes de Pago (PP)')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **MSE**

# %%
MSE = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/MSE.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# %%
# Datos del DataFrame MSE
variables = ['WAPP', 'TP', 'TAD', 'PP']

MSE.set_index('Variable', inplace=True)

# %%
colors = ['#8bc34a', '#009688', '#03a9f4', '#3f51b5', '#673ab7', '#9c27b0', '#9467bd'] #'

#xgboost 8bc34a
#lightgbm 009688
#prophet 03a9f4
#neuralpro 3f51b5
#automl 673ab7
#lstm 9467bd


# Graficar con colores personalizados
MSE.plot(kind='bar', figsize=(10, 6), color=colors, alpha=0.8)
plt.xlabel('Variables')
plt.ylabel('MSE')
plt.title('MSE por modelo para cada variable')
plt.legend(title='Modelos')
plt.tight_layout()

plt.show()

# %% [markdown]
# # **RMSE**

# %%
RMSE = pd.read_excel('C:/Users/jnnov/OneDrive/Documentos/AUSTRAL/MATERIAS/1_CUAT_2DO/SERIES_TEMPORALES/TP 2/RMSE.xlsx')  # Reemplaza 'ruta/del/archivo' con la ubicación real del archivo

# %%
# Datos del DataFrame MSE
variables = ['WAPP', 'TP', 'TAD', 'PP']

RMSE.set_index('VARIABLE', inplace=True)

# %%
colors = ['#8bc34a', '#009688', '#03a9f4', '#3f51b5', '#673ab7', '#9c27b0', '#9467bd'] #'

# Graficar con colores personalizados
RMSE.plot(kind='bar', figsize=(10, 6), color=colors)
plt.xlabel('Variables')
plt.ylabel('RMSE')
plt.title('RMSE por modelo para cada variable')
plt.legend(title='Modelos')
plt.tight_layout()

plt.show()
